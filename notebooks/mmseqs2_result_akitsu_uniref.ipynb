# %%
import polars as pl

# %%
#!/usr/bin/env python3
import re
from collections import defaultdict

# Read FASTA headers
transcript_variants = defaultdict(list)

with open('../Data/tea_convert_akitsu/Mgigas_akitsu_galba.HypotheticalTrans.fa', 'r') as f:
    for line in f:
        if line.startswith('>'):
            match = re.match(r'>g(\d+)\.t(\d+)', line)
            if match:
                gene_id = match.group(1)
                variant_num = int(match.group(2))
                transcript_variants[gene_id].append(variant_num)

# Analyze each gene
missing_lower_variants = []
gaps_in_variants = []

for gene_id in sorted(transcript_variants.keys(), key=int):
    variants = sorted(transcript_variants[gene_id])
    min_variant = min(variants)
    
    # Check if starts from .t1
    if min_variant > 1:
        missing_lower_variants.append((gene_id, min_variant, variants))
    
    # Check for gaps
    for i in range(len(variants) - 1):
        if variants[i+1] != variants[i] + 1:
            gaps_in_variants.append((gene_id, variants[i], variants[i+1], variants))

# Print results
print("=== Genes missing lower transcript variants ===")
print(f"Total: {len(missing_lower_variants)} genes")
for gene_id, min_v, all_v in missing_lower_variants[:20]:  # Show first 20
    missing = list(range(1, min_v))
    print(f"g{gene_id}: starts from .t{min_v}, missing {missing} (has: {all_v})")

if len(missing_lower_variants) > 20:
    print(f"... and {len(missing_lower_variants) - 20} more")

print("\n=== Genes with gaps in transcript variants ===")
print(f"Total: {len(gaps_in_variants)} gaps")
for gene_id, v1, v2, all_v in gaps_in_variants[:20]:  # Show first 20
    print(f"g{gene_id}: gap between .t{v1} and .t{v2} (has: {all_v})")

if len(gaps_in_variants) > 20:
    print(f"... and {len(gaps_in_variants) - 20} more gaps")
# Out:
# === Genes missing lower transcript variants ===
# Total: 44 genes
# g527: starts from .t2, missing [1] (has: [2])
# g1290: starts from .t4, missing [1, 2, 3] (has: [4])
# g2405: starts from .t3, missing [1, 2] (has: [3])
# g4165: starts from .t2, missing [1] (has: [2])
# g5085: starts from .t2, missing [1] (has: [2])
# g6014: starts from .t2, missing [1] (has: [2])
# g6247: starts from .t2, missing [1] (has: [2])
# g6961: starts from .t2, missing [1] (has: [2])
# g7339: starts from .t2, missing [1] (has: [2])
# g7451: starts from .t2, missing [1] (has: [2])
# g7693: starts from .t3, missing [1, 2] (has: [3])
# g9505: starts from .t2, missing [1] (has: [2])
# g10995: starts from .t3, missing [1, 2] (has: [3])
# g12709: starts from .t3, missing [1, 2] (has: [3])
# g15194: starts from .t4, missing [1, 2, 3] (has: [4, 5])
# g18450: starts from .t3, missing [1, 2] (has: [3, 4])
# g18459: starts from .t2, missing [1] (has: [2])
# g20313: starts from .t2, missing [1] (has: [2])
# g20447: starts from .t2, missing [1] (has: [2])
# g23028: starts from .t2, missing [1] (has: [2])
# ... and 24 more
#
# === Genes with gaps in transcript variants ===
# Total: 1 gaps
# g29721: gap between .t1 and .t3 (has: [1, 3])

# %%
mmseqs_result = pl.read_csv(
    "../out/akitsu_uniref50/mmseqs2_easy_search_akitsu_galba_uniref50.tsv",
    separator="\t",
).drop(
    "qheader",
    "theader"
).with_columns(
    # Extract only the gene ID (e.g., "g39065") from the query column
    pl.col("query").str.extract(r'^(g\d+)', group_index=1).alias("Gene_level")
)

print(mmseqs_result.select("Gene_level").unique())
display(mmseqs_result)
# Out:
# shape: (920, 1)
# ┌────────────┐
# │ Gene_level │
# │ ---        │
# │ str        │
# ╞════════════╡
# │ g41315     │
# │ g4100      │
# │ g38034     │
# │ g7724      │
# │ g21823     │
# │ …          │
# │ g18425     │
# │ g2161      │
# │ g15269     │
# │ g26524     │
# │ g8083      │
# └────────────┘
# shape: (358_948, 19)
# ┌─────────────────┬─────────────────┬────────┬────────┬───┬──────┬─────────────┬──────┬────────────┐
# │ query           ┆ target          ┆ pident ┆ fident ┆ … ┆ tend ┆ evalue      ┆ bits ┆ Gene_level │
# │ ---             ┆ ---             ┆ ---    ┆ ---    ┆   ┆ ---  ┆ ---         ┆ ---  ┆ ---        │
# │ str             ┆ str             ┆ f64    ┆ f64    ┆   ┆ i64  ┆ f64         ┆ i64  ┆ str        │
# ╞═════════════════╪═════════════════╪════════╪════════╪═══╪══════╪═════════════╪══════╪════════════╡
# │ g39065.t1|H=0.1 ┆ UniRef50_UPI002 ┆ 80.1   ┆ 0.801  ┆ … ┆ 550  ┆ 0.0         ┆ 1144 ┆ g39065     │
# │ 50              ┆ ED2777B         ┆        ┆        ┆   ┆      ┆             ┆      ┆            │
# │ g39065.t1|H=0.1 ┆ UniRef50_A0A8S3 ┆ 74.8   ┆ 0.748  ┆ … ┆ 840  ┆ 1.0050e-296 ┆ 1023 ┆ g39065     │
# │ 50              ┆ UA93            ┆        ┆        ┆   ┆      ┆             ┆      ┆            │
# │ g39065.t1|H=0.1 ┆ UniRef50_A0A8S3 ┆ 74.9   ┆ 0.749  ┆ … ┆ 679  ┆ 2.6960e-277 ┆ 959  ┆ g39065     │
# │ 50              ┆ RLG5            ┆        ┆        ┆   ┆      ┆             ┆      ┆            │
# │ g39065.t1|H=0.1 ┆ UniRef50_A0A8S3 ┆ 72.3   ┆ 0.723  ┆ … ┆ 489  ┆ 4.3650e-262 ┆ 909  ┆ g39065     │
# │ 50              ┆ TV37            ┆        ┆        ┆   ┆      ┆             ┆      ┆            │
# │ g39065.t1|H=0.1 ┆ UniRef50_UPI003 ┆ 71.4   ┆ 0.714  ┆ … ┆ 497  ┆ 9.2620e-260 ┆ 901  ┆ g39065     │
# │ 50              ┆ AF5F5C2         ┆        ┆        ┆   ┆      ┆             ┆      ┆            │
# │ …               ┆ …               ┆ …      ┆ …      ┆ … ┆ …    ┆ …           ┆ …    ┆ …          │
# │ g14558.t1|H=0.2 ┆ UniRef50_A0ABN7 ┆ 91.6   ┆ 0.916  ┆ … ┆ 377  ┆ 4.9190e-20  ┆ 105  ┆ g14558     │
# │ 52              ┆ SK36            ┆        ┆        ┆   ┆      ┆             ┆      ┆            │
# │ g14558.t1|H=0.2 ┆ UniRef50_A0A2N0 ┆ 87.5   ┆ 0.875  ┆ … ┆ 222  ┆ 7.0310e-20  ┆ 105  ┆ g14558     │
# │ 52              ┆ VKQ2            ┆        ┆        ┆   ┆      ┆             ┆      ┆            │
# │ g14558.t1|H=0.2 ┆ UniRef50_UPI002 ┆ 91.6   ┆ 0.916  ┆ … ┆ 573  ┆ 7.0310e-20  ┆ 105  ┆ g14558     │
# │ 52              ┆ 62F8651         ┆        ┆        ┆   ┆      ┆             ┆      ┆            │
# │ g14558.t1|H=0.2 ┆ UniRef50_A0A7I7 ┆ 91.6   ┆ 0.916  ┆ … ┆ 88   ┆ 1.0050e-19  ┆ 104  ┆ g14558     │
# │ 52              ┆ Q674            ┆        ┆        ┆   ┆      ┆             ┆      ┆            │
# │ g14558.t1|H=0.2 ┆ UniRef50_A0A0C9 ┆ 96.9   ┆ 0.969  ┆ … ┆ 78   ┆ 1.0050e-19  ┆ 104  ┆ g14558     │
# │ 52              ┆ UDW7            ┆        ┆        ┆   ┆      ┆             ┆      ┆            │
# └─────────────────┴─────────────────┴────────┴────────┴───┴──────┴─────────────┴──────┴────────────┘

# %%
mmseqs_result_filter1 = mmseqs_result.filter(
    (pl.col("qcov") > 0.5) &
    (pl.col("tcov") > 0.5)
)

display(mmseqs_result_filter1)
# Out:
# shape: (26_412, 19)
# ┌─────────────────┬─────────────────┬────────┬────────┬───┬──────┬─────────────┬──────┬────────────┐
# │ query           ┆ target          ┆ pident ┆ fident ┆ … ┆ tend ┆ evalue      ┆ bits ┆ Gene_level │
# │ ---             ┆ ---             ┆ ---    ┆ ---    ┆   ┆ ---  ┆ ---         ┆ ---  ┆ ---        │
# │ str             ┆ str             ┆ f64    ┆ f64    ┆   ┆ i64  ┆ f64         ┆ i64  ┆ str        │
# ╞═════════════════╪═════════════════╪════════╪════════╪═══╪══════╪═════════════╪══════╪════════════╡
# │ g39065.t1|H=0.1 ┆ UniRef50_UPI002 ┆ 80.1   ┆ 0.801  ┆ … ┆ 550  ┆ 0.0         ┆ 1144 ┆ g39065     │
# │ 50              ┆ ED2777B         ┆        ┆        ┆   ┆      ┆             ┆      ┆            │
# │ g39065.t1|H=0.1 ┆ UniRef50_A0A8S3 ┆ 74.8   ┆ 0.748  ┆ … ┆ 840  ┆ 1.0050e-296 ┆ 1023 ┆ g39065     │
# │ 50              ┆ UA93            ┆        ┆        ┆   ┆      ┆             ┆      ┆            │
# │ g39065.t1|H=0.1 ┆ UniRef50_A0A8S3 ┆ 72.3   ┆ 0.723  ┆ … ┆ 489  ┆ 4.3650e-262 ┆ 909  ┆ g39065     │
# │ 50              ┆ TV37            ┆        ┆        ┆   ┆      ┆             ┆      ┆            │
# │ g39065.t1|H=0.1 ┆ UniRef50_UPI003 ┆ 71.4   ┆ 0.714  ┆ … ┆ 497  ┆ 9.2620e-260 ┆ 901  ┆ g39065     │
# │ 50              ┆ AF5F5C2         ┆        ┆        ┆   ┆      ┆             ┆      ┆            │
# │ g39065.t1|H=0.1 ┆ UniRef50_A0A8B6 ┆ 73.7   ┆ 0.737  ┆ … ┆ 429  ┆ 1.3740e-257 ┆ 894  ┆ g39065     │
# │ 50              ┆ CD03            ┆        ┆        ┆   ┆      ┆             ┆      ┆            │
# │ …               ┆ …               ┆ …      ┆ …      ┆ … ┆ …    ┆ …           ┆ …    ┆ …          │
# │ g14558.t1|H=0.2 ┆ UniRef50_A0A1L9 ┆ 58.4   ┆ 0.584  ┆ … ┆ 135  ┆ 9.6750e-22  ┆ 111  ┆ g14558     │
# │ 52              ┆ S1C7            ┆        ┆        ┆   ┆      ┆             ┆      ┆            │
# │ g14558.t1|H=0.2 ┆ UniRef50_A0A2G1 ┆ 60.4   ┆ 0.604  ┆ … ┆ 170  ┆ 9.6750e-22  ┆ 111  ┆ g14558     │
# │ 52              ┆ QM74            ┆        ┆        ┆   ┆      ┆             ┆      ┆            │
# │ g14558.t1|H=0.2 ┆ UniRef50_A0A7S1 ┆ 57.0   ┆ 0.57   ┆ … ┆ 93   ┆ 1.9760e-21  ┆ 110  ┆ g14558     │
# │ 52              ┆ VKZ7            ┆        ┆        ┆   ┆      ┆             ┆      ┆            │
# │ g14558.t1|H=0.2 ┆ UniRef50_A0A423 ┆ 63.0   ┆ 0.63   ┆ … ┆ 108  ┆ 4.0380e-21  ┆ 109  ┆ g14558     │
# │ 52              ┆ GPU7            ┆        ┆        ┆   ┆      ┆             ┆      ┆            │
# │ g14558.t1|H=0.2 ┆ UniRef50_A0A481 ┆ 56.6   ┆ 0.566  ┆ … ┆ 182  ┆ 4.0380e-21  ┆ 109  ┆ g14558     │
# │ 52              ┆ Z5M4            ┆        ┆        ┆   ┆      ┆             ┆      ┆            │
# └─────────────────┴─────────────────┴────────┴────────┴───┴──────┴─────────────┴──────┴────────────┘

# %%
UniRef50_list = mmseqs_result_filter1.select(
    pl.col("target")
).unique().write_csv(
    "../out/akitsu_uniref50/akitsu_uniref50_list.txt",
    separator="\n",
    include_header=False
)

# %%
# UniRef50 idmapping (2025-12-21)
akitsu_uniref50_idmapping = pl.read_csv(
    "../out/akitsu_uniref50/akitsu_uniref50_idmapping_20251221.tsv.gz",
    separator="\t"
).sort(
    "Size",
    descending=True
).rename(
    {
        "From": "target"
    }
)

display(akitsu_uniref50_idmapping)
# Out:
# shape: (23_790, 13)
# ┌────────────┬────────────┬────────────┬───────────┬───┬────────┬──────────┬───────────┬───────────┐
# │ target     ┆ Cluster ID ┆ Cluster    ┆ Common    ┆ … ┆ Length ┆ Identity ┆ Cluster   ┆ Date of   │
# │ ---        ┆ ---        ┆ Name       ┆ taxon ID  ┆   ┆ ---    ┆ ---      ┆ members   ┆ last modi │
# │ str        ┆ str        ┆ ---        ┆ ---       ┆   ┆ i64    ┆ f64      ┆ ---       ┆ fication  │
# │            ┆            ┆ str        ┆ i64       ┆   ┆        ┆          ┆ str       ┆ ---       │
# │            ┆            ┆            ┆           ┆   ┆        ┆          ┆           ┆ str       │
# ╞════════════╪════════════╪════════════╪═══════════╪═══╪════════╪══════════╪═══════════╪═══════════╡
# │ UniRef50_A ┆ UniRef50_A ┆ Cluster:   ┆ 2         ┆ … ┆ 117    ┆ 0.5      ┆ A0A5T1QSB ┆ 2025-10-0 │
# │ 0A5T1QSB5  ┆ 0A5T1QSB5  ┆ Methyl-acc ┆           ┆   ┆        ┆          ┆ 5; A0A5T0 ┆ 8         │
# │            ┆            ┆ epting     ┆           ┆   ┆        ┆          ┆ XTJ9;     ┆           │
# │            ┆            ┆ tran…      ┆           ┆   ┆        ┆          ┆ A0A5Z1…   ┆           │
# │ UniRef50_U ┆ UniRef50_U ┆ Cluster:   ┆ 1         ┆ … ┆ 85     ┆ 0.5      ┆ U2J041;   ┆ 2025-10-0 │
# │ 2J041      ┆ 2J041      ┆ Carrier    ┆           ┆   ┆        ┆          ┆ D7VIZ9;   ┆ 8         │
# │            ┆            ┆ domain-con ┆           ┆   ┆        ┆          ┆ A0A380CB8 ┆           │
# │            ┆            ┆ tai…       ┆           ┆   ┆        ┆          ┆ 2; C2…    ┆           │
# │ UniRef50_P ┆ UniRef50_P ┆ Cluster:   ┆ 5740      ┆ … ┆ 273    ┆ 0.5      ┆ P15518;   ┆ 2025-10-0 │
# │ 15518      ┆ 15518      ┆ Giardin    ┆           ┆   ┆        ┆          ┆ A7U7Y3;   ┆ 8         │
# │            ┆            ┆ subunit    ┆           ┆   ┆        ┆          ┆ E2RTU8;   ┆           │
# │            ┆            ┆ beta       ┆           ┆   ┆        ┆          ┆ E2RTU7…   ┆           │
# │ UniRef50_Q ┆ UniRef50_Q ┆ Cluster:   ┆ 2         ┆ … ┆ 158    ┆ 0.5      ┆ Q97QZ2;   ┆ 2025-10-0 │
# │ 97QZ2      ┆ 97QZ2      ┆ Antitoxin  ┆           ┆   ┆        ┆          ┆ A0A098API ┆ 8         │
# │            ┆            ┆ PezA       ┆           ┆   ┆        ┆          ┆ 9; A0A4J1 ┆           │
# │            ┆            ┆            ┆           ┆   ┆        ┆          ┆ Z618…     ┆           │
# │ UniRef50_A ┆ UniRef50_A ┆ Cluster:   ┆ 412133    ┆ … ┆ 294    ┆ 0.5      ┆ A2G4L4;   ┆ 2025-10-0 │
# │ 2G4L4      ┆ 2G4L4      ┆ DUF7777    ┆           ┆   ┆        ┆          ┆ A2DPK4;   ┆ 8         │
# │            ┆            ┆ domain-con ┆           ┆   ┆        ┆          ┆ A2FGN2;   ┆           │
# │            ┆            ┆ tai…       ┆           ┆   ┆        ┆          ┆ A2HEC1…   ┆           │
# │ …          ┆ …          ┆ …          ┆ …         ┆ … ┆ …      ┆ …        ┆ …         ┆ …         │
# │ UniRef50_U ┆ UniRef50_U ┆ Cluster:   ┆ 196820    ┆ … ┆ 336    ┆ 0.5      ┆ UPI00331C ┆ 2024-10-0 │
# │ PI00331C1C ┆ PI00331C1C ┆ E3 SUMO-pr ┆           ┆   ┆        ┆          ┆ 1C2F      ┆ 2         │
# │ 2F         ┆ 2F         ┆ otein      ┆           ┆   ┆        ┆          ┆           ┆           │
# │            ┆            ┆ ligas…     ┆           ┆   ┆        ┆          ┆           ┆           │
# │ UniRef50_U ┆ UniRef50_U ┆ Cluster:   ┆ 196820    ┆ … ┆ 152    ┆ 0.5      ┆ UPI003319 ┆ 2024-10-0 │
# │ PI00331977 ┆ PI00331977 ┆ uncharacte ┆           ┆   ┆        ┆          ┆ 7731      ┆ 2         │
# │ 31         ┆ 31         ┆ rized      ┆           ┆   ┆        ┆          ┆           ┆           │
# │            ┆            ┆ prote…     ┆           ┆   ┆        ┆          ┆           ┆           │
# │ UniRef50_U ┆ UniRef50_U ┆ Cluster:   ┆ 196820    ┆ … ┆ 259    ┆ 0.5      ┆ UPI003318 ┆ 2024-10-0 │
# │ PI003318EE ┆ PI003318EE ┆ uncharacte ┆           ┆   ┆        ┆          ┆ EEA9      ┆ 2         │
# │ A9         ┆ A9         ┆ rized      ┆           ┆   ┆        ┆          ┆           ┆           │
# │            ┆            ┆ prote…     ┆           ┆   ┆        ┆          ┆           ┆           │
# │ UniRef50_U ┆ UniRef50_U ┆ Cluster:   ┆ 196820    ┆ … ┆ 688    ┆ 0.5      ┆ UPI00332A ┆ 2024-10-0 │
# │ PI00332A3F ┆ PI00332A3F ┆ uncharacte ┆           ┆   ┆        ┆          ┆ 3FE0      ┆ 2         │
# │ E0         ┆ E0         ┆ rized      ┆           ┆   ┆        ┆          ┆           ┆           │
# │            ┆            ┆ prote…     ┆           ┆   ┆        ┆          ┆           ┆           │
# │ UniRef50_A ┆ UniRef50_A ┆ Cluster:   ┆ 38457     ┆ … ┆ 527    ┆ 0.5      ┆ A0A395IDF ┆ 2023-02-2 │
# │ 0A395IDF2  ┆ 0A395IDF2  ┆ Uncharacte ┆           ┆   ┆        ┆          ┆ 2         ┆ 2         │
# │            ┆            ┆ rized      ┆           ┆   ┆        ┆          ┆           ┆           │
# │            ┆            ┆ prote…     ┆           ┆   ┆        ┆          ┆           ┆           │
# └────────────┴────────────┴────────────┴───────────┴───┴────────┴──────────┴───────────┴───────────┘

# %%
mmseqs_result_join = mmseqs_result_filter1.join(
    akitsu_uniref50_idmapping,
    on="target",
    how="inner"
).filter(
    (pl.col("evalue") < 1e-5)
).with_columns(
    # Exact match including parentheses (need to escape special regex characters)
    pl.col("Types").str.contains(r"UniProtKB Reviewed \(Swiss-Prot\)").alias("is_reviewed")
    # pl.col("Organism IDs").str.split(";").alias("organism_ids")
).drop(
    "Identity",
    "Cluster members",
    "Date of last modification"
).with_columns(
    # Check if any hit for this gene contains "UniProtKB Reviewed"
    pl.col("is_reviewed").any().over("Gene_level").alias("gene_has_reviewed")
    # pl.col("organism_ids").list.contains("9606").alias("is_human"),
    # pl.col("organism_ids").list.contains("10090").alias("is_mouse")
).sort(
    "query",
    descending=True
)

mmseqs_result_join.write_csv(
    "../out/akitsu_uniref50/mmseqs2_akitsu_galba_uniref50_join.tsv",
    separator="\t"
)

pl.Config.set_fmt_str_lengths(100)
# pl.Config.set_tbl_rows(100)
print(mmseqs_result_join.select("Gene_level").unique())
display(mmseqs_result_join)
# Out:
# shape: (715, 1)
# ┌────────────┐
# │ Gene_level │
# │ ---        │
# │ str        │
# ╞════════════╡
# │ g32917     │
# │ g359       │
# │ g42510     │
# │ g46841     │
# │ g9274      │
# │ …          │
# │ g32207     │
# │ g38142     │
# │ g19200     │
# │ g23452     │
# │ g30967     │
# └────────────┘
# shape: (26_404, 30)
# ┌─────────────┬─────────────┬────────┬────────┬───┬─────────────┬────────┬────────────┬────────────┐
# │ query       ┆ target      ┆ pident ┆ fident ┆ … ┆ Organisms   ┆ Length ┆ is_reviewe ┆ gene_has_r │
# │ ---         ┆ ---         ┆ ---    ┆ ---    ┆   ┆ ---         ┆ ---    ┆ d          ┆ eviewed    │
# │ str         ┆ str         ┆ f64    ┆ f64    ┆   ┆ str         ┆ i64    ┆ ---        ┆ ---        │
# │             ┆             ┆        ┆        ┆   ┆             ┆        ┆ bool       ┆ bool       │
# ╞═════════════╪═════════════╪════════╪════════╪═══╪═════════════╪════════╪════════════╪════════════╡
# │ g995.t1|H=0 ┆ UniRef50_A0 ┆ 64.5   ┆ 0.645  ┆ … ┆ Magallana   ┆ 397    ┆ false      ┆ false      │
# │ .217        ┆ A8W8NUN1    ┆        ┆        ┆   ┆ gigas       ┆        ┆            ┆            │
# │             ┆             ┆        ┆        ┆   ┆ (Pacific    ┆        ┆            ┆            │
# │             ┆             ┆        ┆        ┆   ┆ oyster)     ┆        ┆            ┆            │
# │ g995.t1|H=0 ┆ UniRef50_UP ┆ 61.2   ┆ 0.612  ┆ … ┆ Mizuhopecte ┆ 319    ┆ false      ┆ false      │
# │ .217        ┆ I000B45DCE5 ┆        ┆        ┆   ┆ n           ┆        ┆            ┆            │
# │             ┆             ┆        ┆        ┆   ┆ yessoensis  ┆        ┆            ┆            │
# │ g995.t1|H=0 ┆ UniRef50_A0 ┆ 58.2   ┆ 0.582  ┆ … ┆ Rhipicephal ┆ 301    ┆ false      ┆ false      │
# │ .217        ┆ A9D4QH50    ┆        ┆        ┆   ┆ us          ┆        ┆            ┆            │
# │             ┆             ┆        ┆        ┆   ┆ sanguineus  ┆        ┆            ┆            │
# │             ┆             ┆        ┆        ┆   ┆ (Brown dog  ┆        ┆            ┆            │
# │             ┆             ┆        ┆        ┆   ┆ tick)       ┆        ┆            ┆            │
# │ g995.t1|H=0 ┆ UniRef50_A0 ┆ 61.9   ┆ 0.619  ┆ … ┆ Larimichthy ┆ 248    ┆ false      ┆ false      │
# │ .217        ┆ A6G0IZ97    ┆        ┆        ┆   ┆ s crocea    ┆        ┆            ┆            │
# │             ┆             ┆        ┆        ┆   ┆ (Large      ┆        ┆            ┆            │
# │             ┆             ┆        ┆        ┆   ┆ yellow      ┆        ┆            ┆            │
# │             ┆             ┆        ┆        ┆   ┆ croaker)    ┆        ┆            ┆            │
# │ g995.t1|H=0 ┆ UniRef50_A0 ┆ 70.9   ┆ 0.709  ┆ … ┆ Rhipicephal ┆ 192    ┆ false      ┆ false      │
# │ .217        ┆ A9D4PYS9    ┆        ┆        ┆   ┆ us          ┆        ┆            ┆            │
# │             ┆             ┆        ┆        ┆   ┆ sanguineus  ┆        ┆            ┆            │
# │             ┆             ┆        ┆        ┆   ┆ (Brown dog  ┆        ┆            ┆            │
# │             ┆             ┆        ┆        ┆   ┆ tick)       ┆        ┆            ┆            │
# │ …           ┆ …           ┆ …      ┆ …      ┆ … ┆ …           ┆ …      ┆ …          ┆ …          │
# │ g10056.t1|H ┆ UniRef50_A0 ┆ 48.9   ┆ 0.489  ┆ … ┆ marine      ┆ 475    ┆ false      ┆ false      │
# │ =0.215      ┆ A382A3X7    ┆        ┆        ┆   ┆ metagenome  ┆        ┆            ┆            │
# │ g10056.t1|H ┆ UniRef50_A0 ┆ 43.3   ┆ 0.433  ┆ … ┆ Noctiluca   ┆ 1070   ┆ false      ┆ false      │
# │ =0.215      ┆ A7S1AGA9    ┆        ┆        ┆   ┆ scintillans ┆        ┆            ┆            │
# │             ┆             ┆        ┆        ┆   ┆ (Sea        ┆        ┆            ┆            │
# │             ┆             ┆        ┆        ┆   ┆ sparkle)    ┆        ┆            ┆            │
# │ g10056.t1|H ┆ UniRef50_A0 ┆ 47.1   ┆ 0.471  ┆ … ┆ Emiliania   ┆ 648    ┆ false      ┆ false      │
# │ =0.215      ┆ A0D3JFJ8    ┆        ┆        ┆   ┆ huxleyi     ┆        ┆            ┆            │
# │             ┆             ┆        ┆        ┆   ┆ (strain     ┆        ┆            ┆            │
# │             ┆             ┆        ┆        ┆   ┆ CCMP1516);  ┆        ┆            ┆            │
# │             ┆             ┆        ┆        ┆   ┆ Emiliania   ┆        ┆            ┆            │
# │             ┆             ┆        ┆        ┆   ┆ huxleyi (Co ┆        ┆            ┆            │
# │             ┆             ┆        ┆        ┆   ┆ ccolithopho ┆        ┆            ┆            │
# │             ┆             ┆        ┆        ┆   ┆ re)         ┆        ┆            ┆            │
# │ g10056.t1|H ┆ UniRef50_A0 ┆ 48.3   ┆ 0.483  ┆ … ┆ Adineta     ┆ 752    ┆ false      ┆ false      │
# │ =0.215      ┆ A814WL68    ┆        ┆        ┆   ┆ ricciae     ┆        ┆            ┆            │
# │             ┆             ┆        ┆        ┆   ┆ (Rotifer)   ┆        ┆            ┆            │
# │ g10056.t1|H ┆ UniRef50_A0 ┆ 48.8   ┆ 0.488  ┆ … ┆ Mugilogobiu ┆ 590    ┆ false      ┆ false      │
# │ =0.215      ┆ AAW0NRS5    ┆        ┆        ┆   ┆ s chulae    ┆        ┆            ┆            │
# │             ┆             ┆        ┆        ┆   ┆ (yellowstri ┆        ┆            ┆            │
# │             ┆             ┆        ┆        ┆   ┆ pe goby);   ┆        ┆            ┆            │
# │             ┆             ┆        ┆        ┆   ┆ Nothobranch ┆        ┆            ┆            │
# │             ┆             ┆        ┆        ┆   ┆ ius kuhntae ┆        ┆            ┆            │
# │             ┆             ┆        ┆        ┆   ┆ (Beira      ┆        ┆            ┆            │
# │             ┆             ┆        ┆        ┆   ┆ killifish)  ┆        ┆            ┆            │
# └─────────────┴─────────────┴────────┴────────┴───┴─────────────┴────────┴────────────┴────────────┘

# %%
mmseqs_result_join_filter2 = mmseqs_result_join.filter(
    # (pl.col("gene_has_reviewed") == True) &
    (pl.col("is_reviewed") == True)
).drop(
    "organism_ids"
)

mmseqs_result_join_filter2.write_csv(
    "../out/akitsu_uniref50/mmseqs2_akitsu_galba_uniref50_reviewed.tsv",
    separator="\t"
)

print(mmseqs_result_join_filter2.select("Gene_level").unique())
display(mmseqs_result_join_filter2)
# Out:
# shape: (0, 1)
# ┌────────────┐
# │ Gene_level │
# │ ---        │
# │ str        │
# ╞════════════╡
# └────────────┘
# shape: (0, 32)
# ┌───────┬────────┬────────┬────────┬───┬─────────────┬───────────────────┬──────────┬──────────┐
# │ query ┆ target ┆ pident ┆ fident ┆ … ┆ is_reviewed ┆ gene_has_reviewed ┆ is_human ┆ is_mouse │
# │ ---   ┆ ---    ┆ ---    ┆ ---    ┆   ┆ ---         ┆ ---               ┆ ---      ┆ ---      │
# │ str   ┆ str    ┆ f64    ┆ f64    ┆   ┆ bool        ┆ bool              ┆ bool     ┆ bool     │
# ╞═══════╪════════╪════════╪════════╪═══╪═════════════╪═══════════════════╪══════════╪══════════╡
# └───────┴────────┴────────┴────────┴───┴─────────────┴───────────────────┴──────────┴──────────┘
